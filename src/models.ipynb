# %%
import os
os.environ.get?
# Out:
# Signature: os.environ.get(key, default=None)
# Docstring: D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.
# File:      ~/github/opinion_mining/src/<frozen _collections_abc>
# Type:      method
